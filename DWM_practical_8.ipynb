# %%
import numpy as np
import matplotlib.pyplot as mtp
import pandas as pd

# %%
#import os
#os.getcwd() : change working directory

# %%
#importing the dataset
dataset = pd.read_csv("/content/demo1.csv")

# %%
x = dataset.iloc[:, [1, 2]].values
x
# Out:
# array([[1011,  953],
#        [1012,  983],
#        [1012,  980],
#        [1013,  975],
#        [1013,  970],
#        [1013,  971],
#        [1015,  969],
#        [1017,  967],
#        [1017,  968],
#        [1016,  966],
#        [1012,  933],
#        [1010,  937],
#        [1012,  940],
#        [1013,  945],
#        [1008,  924],
#        [1007,  595],
#        [ 771,  767],
#        [ 741,  748],
#        [ 752,  722],
#        [ 733,  813],
#        [ 731,  767],
#        [ 249,  261],
#        [ 325,  344],
#        [1011,  991],
#        [1010,  487],
#        [1012,  572],
#        [1018, 1016],
#        [1016, 1023],
#        [ 511, 1018],
#        [1014, 1020],
#        [1011, 1016],
#        [1010, 1013],
#        [1011, 1014],
#        [1012, 1016],
#        [ 897,  508],
#        [ 781,  534],
#        [ 746,  512],
#        [ 306,  255],
#        [ 198,  175],
#        [ 490,  457],
#        [ 788,  514],
#        [ 959, 1016],
#        [ 976, 1016],
#        [ 983, 1015],
#        [ 976, 1016],
#        [ 971, 1015],
#        [ 973, 1015],
#        [ 976, 1016],
#        [ 978, 1016],
#        [ 981, 1016],
#        [ 985, 1016],
#        [ 976, 1023],
#        [ 981,  996],
#        [ 983,  466],
#        [ 984,  897],
#        [ 984, 1007],
#        [ 980, 1005],
#        [ 982, 1007],
#        [ 984, 1007],
#        [ 986, 1009],
#        [ 990, 1013],
#        [ 994, 1018],
#        [ 994, 1019],
#        [ 993, 1018],
#        [ 992, 1018],
#        [ 991, 1018],
#        [ 992, 1019],
#        [ 991, 1019],
#        [ 991, 1018],
#        [ 991, 1019],
#        [ 990, 1018],
#        [ 987, 1015],
#        [ 983, 1009],
#        [ 983, 1008],
#        [ 985, 1009],
#        [ 986, 1010],
#        [ 988, 1012],
#        [ 992, 1017],
#        [ 994, 1022],
#        [ 993, 1022],
#        [ 992, 1021],
#        [ 991, 1021],
#        [ 992, 1021],
#        [ 992, 1022],
#        [ 994, 1021],
#        [ 993, 1018],
#        [ 990, 1014],
#        [ 988, 1011],
#        [ 986, 1010],
#        [ 987, 1011],
#        [ 985, 1009],
#        [ 988, 1015],
#        [ 993, 1021],
#        [ 994, 1020],
#        [ 991, 1016],
#        [ 988, 1012],
#        [ 986, 1010],
#        [ 986, 1009],
#        [ 984, 1006],
#        [ 986, 1011],
#        [ 990, 1017],
#        [ 994, 1023],
#        [ 995, 1021],
#        [ 991, 1016],
#        [ 989, 1012],
#        [ 987, 1010],
#        [ 986, 1009],
#        [ 986, 1009],
#        [ 986, 1011],
#        [ 990, 1016],
#        [ 995, 1023],
#        [ 994, 1019],
#        [ 988, 1011],
#        [ 986, 1006],
#        [ 993, 1020],
#        [ 994, 1018],
#        [ 988, 1010],
#        [ 986, 1009],
#        [ 993, 1019],
#        [ 995, 1018],
#        [ 989, 1010],
#        [ 986, 1009],
#        [ 995, 1021],
#        [ 989, 1010],
#        [ 987, 1010],
#        [ 995, 1021],
#        [ 989, 1011],
#        [ 986, 1008],
#        [ 990, 1014],
#        [ 993, 1017],
#        [ 990, 1010],
#        [ 987, 1007],
#        [ 989, 1012],
#        [ 995, 1018],
#        [ 992, 1012]])

# %%
y = dataset.iloc[:, 3].values
y
# Out:
# array(['d', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd',
#        'd', 'd', 'd', 'm', 'm', 'm', 'm', 'm', 'w', 'w', 'd', 'd', 'd',
#        'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'm', 'm', 'm', 'w', 'w',
#        'w', 'm', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd',
#        'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd',
#        'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd',
#        'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd',
#        'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd',
#        'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd',
#        'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd',
#        'd', 'd', 'd', 'd', 'd'], dtype=object)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 0)

#feature scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
print(x_train)
print(x_test)
# Out:
# [[ 0.28660539  0.42614851]
#  [ 0.33277308  0.44227276]
#  [ 0.24043769  0.37240101]
#  [ 0.29320077  0.40464951]
#  [ 0.3261777   0.43689801]
#  [ 0.45808539  0.049916  ]
#  [ 0.21405615  0.43152326]
#  [ 0.3261777   0.44764751]
#  [ 0.28001     0.39390001]
#  [ 0.33277308  0.45839702]
#  [ 0.41851308 -1.83124659]
#  [ 0.30639154  0.41539901]
#  [-1.0258762  -2.26660135]
#  [ 0.28001     0.39390001]
#  [ 0.29979616  0.41002426]
#  [ 0.45808539  0.2111585 ]
#  [ 0.28660539  0.39927476]
#  [ 0.33277308  0.44764751]
#  [ 0.47127616  0.17891   ]
#  [ 0.33277308  0.46914652]
#  [ 0.28001     0.39390001]
#  [ 0.30639154  0.43152326]
#  [ 0.26022385  0.38852526]
#  [ 0.29979616  0.39927476]
#  [ 0.33277308  0.46377177]
#  [ 0.31958231  0.44764751]
#  [ 0.28001     0.39927476]
#  [ 0.28001     0.40464951]
#  [ 0.47787155  0.46914652]
#  [-1.26331005 -1.14865331]
#  [ 0.33936847  0.44227276]
#  [ 0.43829924  0.006918  ]
#  [ 0.30639154  0.42077376]
#  [ 0.29320077  0.42614851]
#  [ 0.10193461  0.43152326]
#  [ 0.33277308  0.45302226]
#  [ 0.45149001  0.25415651]
#  [ 0.28660539  0.40464951]
#  [ 0.33936847  0.45839702]
#  [ 0.21405615  0.43152326]
#  [ 0.45808539  0.18428475]
#  [-1.33585929 -1.0089098 ]
#  [-4.91715326 -4.08864168]
#  [ 0.45808539  0.1896595 ]
#  [ 0.26022385 -2.52458937]
#  [ 0.30639154  0.42077376]
#  [ 0.33277308  0.44227276]
#  [ 0.44489462  0.092914  ]
#  [-0.30697925 -2.29884986]
#  [-2.8527978   0.44227276]
#  [ 0.26681923  0.38315051]
#  [ 0.28001     0.39927476]
#  [-1.07204389 -2.15910635]
#  [ 0.44489462  0.29715451]
#  [ 0.27341462  0.39390001]
#  [ 0.43829924  0.41539901]
#  [ 0.31298693  0.43152326]
#  [ 0.25362846  0.38315051]
#  [ 0.33936847  0.46914652]
#  [ 0.28001     0.39390001]
#  [ 0.44489462  0.42077376]
#  [ 0.33936847  0.44227276]
#  [ 0.42510847 -0.06295376]
#  [ 0.26681923  0.37777576]
#  [-1.38862236 -0.65955103]
#  [ 0.46468078  0.45302226]
#  [ 0.24703308  0.43152326]
#  [ 0.29320077  0.39927476]
#  [ 0.28001     0.40464951]
#  [ 0.31958231  0.45839702]
#  [ 0.31958231  0.44227276]
#  [ 0.31958231  0.41002426]
#  [ 0.3261777   0.46377177]
#  [ 0.31298693  0.44764751]
#  [ 0.31958231  0.45839702]
#  [-1.40181313 -0.90678954]
#  [ 0.30639154  0.39927476]
#  [ 0.26022385  0.39390001]
#  [ 0.31958231  0.43689801]
#  [ 0.45149001 -1.95486584]
#  [-4.2048517  -3.65866167]
#  [ 0.31298693  0.45839702]
#  [ 0.28660539  0.39927476]
#  [ 0.19427     0.42614851]
#  [ 0.28001     0.38852526]
#  [-2.99130088 -2.57296212]
#  [ 0.33936847  0.45839702]
#  [ 0.31298693  0.44227276]
#  [ 0.26681923  0.38315051]
#  [ 0.45149001  0.02304225]
#  [ 0.33936847  0.45839702]
#  [ 0.28001     0.39927476]
#  [ 0.30639154  0.44227276]
#  [ 0.29320077  0.40464951]
#  [-1.30288236 -2.27735085]
#  [-4.58078863 -3.62641316]
#  [ 0.47787155  0.16278575]
#  [ 0.31298693  0.43152326]
#  [ 0.31298693  0.44764751]
#  [ 0.28001     0.39390001]
#  [ 0.21405615  0.43152326]]
# [[ 0.29979616  0.39927476]
#  [ 0.45149001  0.43152326]
#  [ 0.18107923  0.42614851]
#  [ 0.29979616  0.40464951]
#  [ 0.31958231  0.46377177]
#  [ 0.48446693  0.17353525]
#  [ 0.24703308  0.32402826]
#  [ 0.29979616  0.41002426]
#  [-4.07953938 -3.18030889]
#  [ 0.28001     0.37777576]
#  [ 0.22724692  0.43152326]
#  [ 0.28001     0.39390001]
#  [ 0.43829924 -2.41171961]
#  [ 0.29320077  0.41002426]
#  [ 0.26022385  0.42614851]
#  [ 0.27341462  0.39390001]
#  [ 0.26681923 -0.20807201]
#  [ 0.31298693  0.44227276]
#  [ 0.28660539  0.38315051]
#  [ 0.3261777   0.45839702]
#  [ 0.48446693  0.1681605 ]
#  [ 0.49106232  0.43152326]
#  [ 0.29320077  0.41002426]
#  [ 0.45149001 -0.01458101]
#  [ 0.33277308  0.44764751]
#  [ 0.30639154  0.43689801]
#  [-1.13799774 -0.90678954]
#  [ 0.45149001  0.23803226]
#  [ 0.21405615  0.46914652]
#  [ 0.3261777   0.44227276]
#  [ 0.3261777   0.44227276]
#  [ 0.27341462  0.43152326]
#  [ 0.44489462  0.43152326]
#  [ 0.3261777   0.45302226]]

# %%
#fitting naive bayes to the training set
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
GaussianNB()
# Out:
# GaussianNB()

# %%
print(x_test)
# Out:
# [[ 0.29979616  0.39927476]
#  [ 0.45149001  0.43152326]
#  [ 0.18107923  0.42614851]
#  [ 0.29979616  0.40464951]
#  [ 0.31958231  0.46377177]
#  [ 0.48446693  0.17353525]
#  [ 0.24703308  0.32402826]
#  [ 0.29979616  0.41002426]
#  [-4.07953938 -3.18030889]
#  [ 0.28001     0.37777576]
#  [ 0.22724692  0.43152326]
#  [ 0.28001     0.39390001]
#  [ 0.43829924 -2.41171961]
#  [ 0.29320077  0.41002426]
#  [ 0.26022385  0.42614851]
#  [ 0.27341462  0.39390001]
#  [ 0.26681923 -0.20807201]
#  [ 0.31298693  0.44227276]
#  [ 0.28660539  0.38315051]
#  [ 0.3261777   0.45839702]
#  [ 0.48446693  0.1681605 ]
#  [ 0.49106232  0.43152326]
#  [ 0.29320077  0.41002426]
#  [ 0.45149001 -0.01458101]
#  [ 0.33277308  0.44764751]
#  [ 0.30639154  0.43689801]
#  [-1.13799774 -0.90678954]
#  [ 0.45149001  0.23803226]
#  [ 0.21405615  0.46914652]
#  [ 0.3261777   0.44227276]
#  [ 0.3261777   0.44227276]
#  [ 0.27341462  0.43152326]
#  [ 0.44489462  0.43152326]
#  [ 0.3261777   0.45302226]]

# %%
#predicting the test set results
y_pred = classifier.predict(x_test)
y_pred
# Out:
# array(['d', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'w', 'd', 'd', 'd', 'm',
#        'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd',
#        'm', 'd', 'd', 'd', 'd', 'd', 'd', 'd'], dtype='<U1')

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[31,  1,  0],
#        [ 0,  1,  0],
#        [ 0,  0,  1]])

# %%
y_pred = classifier.predict([[275, 1111]])
print(y_pred)
# Out:
# ['m']
